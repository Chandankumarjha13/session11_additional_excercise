# %% [markdown]
# # 11.STATISTICS - 1- Additional Excercise-2

# %% [markdown]
# # Problem Statement 1: [50 marks]
# The marks awarded for an assignment set for a Year 8 class of 20 students were as follows:
# 6 7 5 7 7 8 7 6 9 7 4 10 6 8 8 9 5 6 4 8
# Calculate the mean, median, mode and standard deviation for the problem statements

# %%
from math import sqrt
def findMean(markList):
    return sum(markList)/len(markList)

def findMedian(markList):
    n = len(markList)
    if n < 1:
            return None
    if n % 2 == 1:
            return sorted(markList)[n//2]
    else:
            return sum(sorted(markList)[n//2-1:n//2+1])/2.0

def findVariance(markList):
    variance = 0.0
    mean = findMean(markList)
    variance = sum((mark - mean)**2 for mark in markList) / (len(markList)-1)
    return variance

def findStandardDeviation(markList):
    return findVariance(markList)**0.5

def findMode(markList):
    return max(set(markList), key=markList.count)


markList = [6 ,7, 5, 7, 7, 8, 7, 6, 9, 7, 4, 10, 6, 8, 8, 9, 5, 6, 4, 8]
print ("Mean = " + str(findMean(markList)))
print ("Median = " + str(findMedian(markList)))
print ("Mode = " + str(findMode(markList)))
print ("variance =" + str(findVariance(markList)))
print("Standard Deviation =" + str(findStandardDeviation(markList)))
# Out:
# Mean = 6.85
# Median = 7.0
# Mode = 7
# variance =2.660526315789474
# Standard Deviation =1.6311119875071343

# %% [markdown]
# Output:
#
# Mean = 6.85
# Median = 7.0
# Mode = 7
# variance =2.660526315789474
# Standard Deviation =1.6311119875071343

# %% [markdown]
# # Problem Statement 2:
# The number of calls from motorists per day for roadside service was recorded for a particular month:
# 28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170, 100, 75, 104, 97, 75,
# 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109

# %%
import statistics

callCountList = [28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170, 
       100, 75, 104, 97, 75, 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109]

mean = statistics.mean(callCountList)


median = statistics.median(callCountList)


mode = statistics.mode(callCountList)

stdev = statistics.stdev(callCountList)


variance = statistics.variance(callCountList)

print ("Mean = " ,mean)
print ("Median = ",median)
print ("Mode = ",mode)
print ("variance ", variance)
print("Standard Deviation =", stdev)
# Out:
# Mean =  107.51428571428572
# Median =  100
# Mode =  75
# variance  1547.5512605042018
# Standard Deviation = 39.33892805484412

# %%
Output:
    
Mean =  107.51428571428572
Median =  100
Mode =  75
variance  1547.5512605042018
Standard Deviation = 39.33892805484412
    
print ("Mean = " + str(findMean(markList)))
print ("Median = " + str(findMedian(markList)))
print ("Mode = " + str(findMode(markList)))
print ("variance =" + str(findVariance(markList)))
print("Standard Deviation =" + str(findStandardDeviation(markList)))

# %% [markdown]
# # Problem Statement 3: [100 marks]
# The number of times I go to the gym in weekdays, are given below along with its associated probability:
#
# x = 0, 1, 2, 3, 4, 5
#
# f(x) = 0.09, 0.15, 0.40, 0.25, 0.10, 0.01
#
# Calculate the mean no. of workouts in a week. Also evaluate the variance involved in it.

# %%
import statistics as stat
from math import sqrt 
x=[0,1,2,3,4,5]
func_x = [0.09, 0.15, 0.40, 0.25, 0.10, 0.01]
mean=0
variance =0
for n in range(len(x)):
    mean += x[n]*func_x[n]
print("Mean no. of workouts in a week or Expected Value = ",mean )
for n in range(len(x)):
    variance += (x[n]-mean)**2 * func_x[n]
print("Variance  = ", variance)
# Out:
# Mean no. of workouts in a week or Expected Value =  2.15
# Variance  =  1.2275

# %% [markdown]
# # Problem Statement 4: [100 marks]
# Let the continuous random variable D denote the diameter of the hole drilled in an aluminum sheet. The
# target diameter to be achieved is 12.5mm. Random disturbances in the process often result in inaccuracy.
# Historical data shows that the distribution of D can be modelled by the PDF 𝑓(𝑑) = 20𝑒−20(𝑑−12.5), 𝑑 ≥
# 12.5. If a part with diameter > 12.6 mm needs to be scrapped, what is the proportion of those parts? What
# is the CDF when the diameter is of 11 mm? What is your conclusion regarding the proportion of scraps?

# %%
from IPython.display import Image
Image(filename='IMG_20190207_094005.jpg')

# %% [markdown]
# ![title](/home/chandan/Desktop/ASSIGNMENT/session11/IMG_20190207_094005.jpg)

# %% [markdown]
# ![](/home/chandan/Desktop/ASSIGNMENT/session11/IMG_20190207_094005.jpg)
